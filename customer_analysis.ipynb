# %% [markdown]
# ## <p style="text-align: center;">Activity 3 - Mittwoch</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data= pd.read_csv("Data_Marketing_Customer_Analysis_Round3.csv")

# %%
data.head()
# Out:
#         region  customer_lifetime_value response  coverage education  \
# 0      central                     4809       no     basic   college
# 1  west region                     2228       no     basic   college
# 2         east                    14947       no     basic  bachelor
# 3   north west                    22332      yes  extended   college
# 4   north west                     9025       no   premium  bachelor
#
#   effective_to_date month employment_status gender  income  ...  \
# 0           2/18/11   feb          employed      m   48029  ...
# 1           1/18/11   jan        unemployed      f   92260  ...
# 2           2/10/11   feb          employed      m   22139  ...
# 3           1/11/11   jan          employed      m   49078  ...
# 4           1/17/11   jan     medical leave      f   23675  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                         0                   9
# 1                            26                         0                   1
# 2                            31                         0                   2
# 3                             3                         0                   2
# 4                            31                         0                   7
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  corporate auto  corporate l3            offer3          agent
# 1   personal auto   personal l3            offer4    call center
# 2   personal auto   personal l3            offer3    call center
# 3  corporate auto  corporate l3            offer2         branch
# 4   personal auto   personal l2            offer1         branch
#
#   total_claim_amount  vehicle_class vehicle_size
# 0                292  four-door car      medsize
# 1                744  four-door car      medsize
# 2                480            suv      medsize
# 3                484  four-door car      medsize
# 4                707  four-door car      medsize
#
# [5 rows x 24 columns]

# %%
data=data.drop(columns=["effective_to_date"], axis=1)

# %%
numeric= data.select_dtypes(include=np.number)

# %%
numeric
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# 2                           34                             31
# 3                           10                              3
# 4                           33                             31
# ...                        ...                            ...
# 10684                       12                             40
# 10685                        7                             68
# 10686                       11                             63
# 10687                        0                             27
# 10688                       31                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                              0                   9                 292
# 1                              0                   1                 744
# 2                              0                   2                 480
# 3                              0                   2                 484
# 4                              0                   7                 707
# ...                          ...                 ...                 ...
# 10684                          0                   7                1214
# 10685                          0                   6                 273
# 10686                          0                   2                 381
# 10687                          4                   6                 618
# 10688                          0                   3                1021
#
# [10689 rows x 8 columns]

# %%
data.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'total_claim_amount']

# %%
categoricals= data.select_dtypes(include=["object"])

# %%
data.select_dtypes(include=["object"]).columns.tolist()
# Out:
# ['region',
#  'response',
#  'coverage',
#  'education',
#  'month',
#  'employment_status',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size']

# %%
categoricals
# Out:
#             region response  coverage education month employment_status  \
# 0          central       no     basic   college   feb          employed
# 1      west region       no     basic   college   jan        unemployed
# 2             east       no     basic  bachelor   feb          employed
# 3       north west      yes  extended   college   jan          employed
# 4       north west       no   premium  bachelor   jan     medical leave
# ...            ...      ...       ...       ...   ...               ...
# 10684      central       no   premium  bachelor   jan        unemployed
# 10685   north west       no     basic   college   jan          employed
# 10686      central       no  extended  bachelor   feb          employed
# 10687  west region       no   premium   college   feb          employed
# 10688      central       no     basic  bachelor   jan        unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# 0          m      suburban        married  corporate auto  corporate l3
# 1          f      suburban         single   personal auto   personal l3
# 2          m      suburban         single   personal auto   personal l3
# 3          m      suburban         single  corporate auto  corporate l3
# 4          f      suburban        married   personal auto   personal l2
# ...      ...           ...            ...             ...           ...
# 10684      f      suburban        married   personal auto   personal l1
# 10685      f         urban        married   personal auto   personal l3
# 10686      f         rural        married  corporate auto  corporate l3
# 10687      f         urban       divorced   personal auto   personal l1
# 10688      m      suburban         single   personal auto   personal l1
#
#       renew_offer_type sales_channel  vehicle_class vehicle_size
# 0               offer3         agent  four-door car      medsize
# 1               offer4   call center  four-door car      medsize
# 2               offer3   call center            suv      medsize
# 3               offer2        branch  four-door car      medsize
# 4               offer1        branch  four-door car      medsize
# ...                ...           ...            ...          ...
# 10684           offer3           web     luxury car      medsize
# 10685           offer2        branch  four-door car      medsize
# 10686           offer1           web     luxury suv      medsize
# 10687           offer1        branch            suv      medsize
# 10688           offer4           web            suv      medsize
#
# [10689 rows x 15 columns]

# %%
## first axis
fig=plt.figure(figsize=(30,20))

plt.subplot(4,2,1)
plt.hist(numeric["customer_lifetime_value"]);
plt.xlabel("customer lifetime value");

#second axis
plt.subplot(4,2,2)
plt.hist(numeric["income"]);
plt.xlabel("income");
#plt.title("this is a title")

##. third subplot
plt.subplot(4,2,3)
plt.hist(numeric["monthly_premium_auto"]);
plt.xlabel("monthly_premium_auto");

## fourth subplot
plt.subplot(4,2,4)
#plt.plot(x,-x,color="#e65ead")
plt.hist(numeric["months_since_last_claim"]);
plt.xlabel("months since last claim");

plt.subplot(4,2,5)
plt.hist(numeric["months_since_policy_inception"]);
plt.xlabel("months since policy inception");

plt.subplot(4,2,6)
plt.hist(numeric["number_of_open_complaints"]);
plt.xlabel("number of open complaints");

plt.subplot(4,2,7)
plt.hist(numeric["number_of_policies"]);
plt.xlabel("number of policies");

plt.subplot(4,2,8)
plt.hist(numeric["total_claim_amount"]);
plt.xlabel("total claim amount");


#plt.xlabel("this is x for the fourth subplot")

#plt.suptitle("this the whole figure title")

# %%
numeric.hist(figsize=(30,20));

# %%
sns.histplot(categoricals, x="response");

# %%
sns.histplot(categoricals, x="region");

# %% [markdown]
# ### Subplots with Seaborn

# %%
fig, axes = plt.subplots(4, 2, figsize=(20, 30))

#fig.suptitle('Pokemon Stats by Generation')

sns.histplot(ax=axes[0,0], data=numeric, x='customer_lifetime_value', color= "r")
sns.histplot(ax=axes[0,1], data=numeric, x='income', color= "g")
sns.histplot(ax=axes[1,0], data=numeric, x='monthly_premium_auto', color= "y")
sns.histplot(ax=axes[1,1], data=numeric, x='months_since_last_claim')
sns.histplot(ax=axes[2,0], data=numeric, x='months_since_policy_inception', color= "m")
sns.histplot(ax=axes[2,1], data=numeric, x='number_of_open_complaints', color= "b")
sns.histplot(ax=axes[3,0], data=numeric, x='number_of_policies')
sns.histplot(ax=axes[3,1], data=numeric, x='total_claim_amount');

#sns.boxplot(ax=axes[0, 1], data=po, x='Generation', y='Defense')
#sns.boxplot(ax=axes[0, 2], data=pokemon, x='Generation', y='Speed')
#sns.boxplot(ax=axes[1, 0], data=pokemon, x='Generation', y='Sp. Atk')
#sns.boxplot(ax=axes[1, 1], data=pokemon, x='Generation', y='Sp. Def')
#sns.boxplot(ax=axes[1, 2], data=pokemon, x='Generation', y='HP')

# %% [markdown]
# ### Correlations

# %%
correlations = numeric.corr().unstack().sort_values(ascending=False)

# %%
correlations = pd.DataFrame(correlations).reset_index()

# %%
correlations.columns = ['col1', 'col2', 'correlation']

# %%
correlations
# Out:
#                              col1                           col2  correlation
# 0         customer_lifetime_value        customer_lifetime_value     1.000000
# 1                          income                         income     1.000000
# 2              number_of_policies             number_of_policies     1.000000
# 3       number_of_open_complaints      number_of_open_complaints     1.000000
# 4   months_since_policy_inception  months_since_policy_inception     1.000000
# ..                            ...                            ...          ...
# 59        customer_lifetime_value      number_of_open_complaints    -0.032371
# 60  months_since_policy_inception        months_since_last_claim    -0.034086
# 61        months_since_last_claim  months_since_policy_inception    -0.034086
# 62             total_claim_amount                         income    -0.111221
# 63                         income             total_claim_amount    -0.111221
#
# [64 rows x 3 columns]

# %% [markdown]
# ### Filter by variable

# %%
correlations.query("col1 == 'v2' & col2 != 'v2'")
# Out:
# Empty DataFrame
# Columns: [col1, col2, correlation]
# Index: []

# %% [markdown]
# ### Heatmap

# %%
fig=plt.figure(figsize=(16,9))
heat= sns.heatmap(numeric.corr(),annot=True);
heat.tick_params(axis='x', rotation=45)

# %% [markdown]
# ### THURSDAY

# %%
sns.histplot(categoricals, x="response");

# %% [markdown]
# ## Show a plot of the response by the sales channel.

# %%
class_sales=categoricals.groupby(['sales_channel','response'])['response'].count().rename('count').reset_index()

# %%
class_sales
# Out:
#   sales_channel response  count
# 0         agent       no   3340
# 1         agent      yes    679
# 2        branch       no   2665
# 3        branch      yes    310
# 4   call center       no   1890
# 5   call center      yes    209
# 6           web       no   1421
# 7           web      yes    175

# %%
#class_sales[response_rate]= iloc[i:3]/(iloc[i:3]+iloc[i+1:4]) for i in range (len.class_sales) if (iloc[i:3]==iloc[i+1:4]) else 1-(iloc[i:3]/(iloc[i:3]+iloc[i+1:4]))

# %%
type(class_sales.iloc[0,2])
# Out:
# numpy.int64

# %%
list_test=[]

for i in range (len(class_sales["count"])): 
    a=i
    list_test.append(a)

# %%
list_test
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
len(class_sales["count"])
# Out:
# 8

# %%
list=[]

for i in range (len(class_sales["count"])): 
    
    if (i%2==0):
        a= class_sales.iloc[i,2]/(class_sales.iloc[i,2]+class_sales.iloc[i+1, 2])
        list.append(a)
    else: 
        a=class_sales.iloc[i,2]/(class_sales.iloc[i,2]+class_sales.iloc[i-1, 2])
        list.append(a)

# %%
list
# Out:
# [0.8310525006220453,
#  0.16894749937795472,
#  0.8957983193277311,
#  0.10420168067226891,
#  0.9004287756074321,
#  0.0995712243925679,
#  0.8903508771929824,
#  0.10964912280701754]

# %%
class_sales["rate_res"]=list

# %%
class_sales
# Out:
#   sales_channel response  count  rate_res
# 0         agent       no   3340  0.831053
# 1         agent      yes    679  0.168947
# 2        branch       no   2665  0.895798
# 3        branch      yes    310  0.104202
# 4   call center       no   1890  0.900429
# 5   call center      yes    209  0.099571
# 6           web       no   1421  0.890351
# 7           web      yes    175  0.109649

# %%
categoricals.head()
# Out:
#         region response  coverage education month employment_status gender  \
# 0      central       no     basic   college   feb          employed      m
# 1  west region       no     basic   college   jan        unemployed      f
# 2         east       no     basic  bachelor   feb          employed      m
# 3   north west      yes  extended   college   jan          employed      m
# 4   north west       no   premium  bachelor   jan     medical leave      f
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      suburban        married  corporate auto  corporate l3           offer3
# 1      suburban         single   personal auto   personal l3           offer4
# 2      suburban         single   personal auto   personal l3           offer3
# 3      suburban         single  corporate auto  corporate l3           offer2
# 4      suburban        married   personal auto   personal l2           offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         agent  four-door car      medsize
# 1   call center  four-door car      medsize
# 2   call center            suv      medsize
# 3        branch  four-door car      medsize
# 4        branch  four-door car      medsize

# %%
sns.barplot(x = class_sales['sales_channel'],y = class_sales['count'], hue = class_sales['response']);

# %%
sns.countplot(x="sales_channel", hue="response", data=categoricals);

# %% [markdown]
# ### Show a plot of the response by the total claim amount.

# %%
#sns.countplot(x="total_claim_amount", hue="response", data=data)

# %%
sns.displot(data, x="total_claim_amount", hue="response", bins=50).fig.set_size_inches(15,6);

# %% [markdown]
# ### Show a plot of the response by income.

# %%
sns.displot(data, x="income", hue="response", bins=30, kde=True).set(title= "Total number of responses by income").fig.set_size_inches(15,6);

# %%
sns.histplot(x= class_sales['sales_channel'], y= class_sales['response'], hue =class_sales['response']);
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='response'>

# %%
type(class_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
class_sales
# Out:
#   sales_channel response  count
# 0         agent       no   3340
# 1         agent      yes    679
# 2        branch       no   2665
# 3        branch      yes    310
# 4   call center       no   1890
# 5   call center      yes    209
# 6           web       no   1421
# 7           web      yes    175

# %%
data["total_revenue"]=data["monthly_premium_auto"]*data["months_since_policy_inception"]

# %%
data["total_profit"]=data["total_revenue"]-data["total_claim_amount"]

# %%
data["percent_profit"]=data["total_profit"]/data["total_revenue"]

# %%
data
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       month employment_status gender  income location_code  ...  \
# 0       feb          employed      m   48029      suburban  ...
# 1       jan        unemployed      f   92260      suburban  ...
# 2       feb          employed      m   22139      suburban  ...
# 3       jan          employed      m   49078      suburban  ...
# 4       jan     medical leave      f   23675      suburban  ...
# ...     ...               ...    ...     ...           ...  ...
# 10684   jan        unemployed      f   61541      suburban  ...
# 10685   jan          employed      f   61146         urban  ...
# 10686   feb          employed      f   39837         rural  ...
# 10687   feb          employed      f   64195         urban  ...
# 10688   jan        unemployed      m   68942      suburban  ...
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      corporate auto  corporate l3            offer3          agent
# 1       personal auto   personal l3            offer4    call center
# 2       personal auto   personal l3            offer3    call center
# 3      corporate auto  corporate l3            offer2         branch
# 4       personal auto   personal l2            offer1         branch
# ...               ...           ...               ...            ...
# 10684   personal auto   personal l1            offer3            web
# 10685   personal auto   personal l3            offer2         branch
# 10686  corporate auto  corporate l3            offer1            web
# 10687   personal auto   personal l1            offer1         branch
# 10688   personal auto   personal l1            offer4            web
#
#        total_claim_amount  vehicle_class vehicle_size total_revenue  \
# 0                     292  four-door car      medsize          3172
# 1                     744  four-door car      medsize          1664
# 2                     480            suv      medsize          3100
# 3                     484  four-door car      medsize           291
# 4                     707  four-door car      medsize          3627
# ...                   ...            ...          ...           ...
# 10684                1214     luxury car      medsize         10120
# 10685                 273  four-door car      medsize          4420
# 10686                 381     luxury suv      medsize         12663
# 10687                 618            suv      medsize          4266
# 10688                1021            suv      medsize           101
#
#       total_profit percent_profit
# 0             2880       0.907945
# 1              920       0.552885
# 2             2620       0.845161
# 3             -193      -0.663230
# 4             2920       0.805073
# ...            ...            ...
# 10684         8906       0.880040
# 10685         4147       0.938235
# 10686        12282       0.969912
# 10687         3648       0.855134
# 10688         -920      -9.108911
#
# [10689 rows x 26 columns]

# %%
data[data["percent_profit"]>=0.90]
# Out:
#             region  customer_lifetime_value response  coverage  \
# 0          central                     4809       no     basic
# 5      west region                     4745      yes     basic
# 6      west region                     5035       no     basic
# 7      west region                     4956       no     basic
# 12      north west                    19955       no  extended
# ...            ...                      ...      ...       ...
# 10675   north west                    19776       no  extended
# 10676      central                     9075      yes     basic
# 10682      central                     2771       no     basic
# 10685   north west                     5259       no     basic
# 10686      central                    23893       no  extended
#
#                   education month employment_status gender  income  \
# 0                   college   feb          employed      m   48029
# 5      high school or below   feb          employed      m   50549
# 6                    doctor   feb          employed      f   37405
# 7      high school or below   feb          employed      m   87197
# 12     high school or below   jan          employed      f   69096
# ...                     ...   ...               ...    ...     ...
# 10675  high school or below   jan          employed      f   70699
# 10676                master   jan          employed      m   37722
# 10682               college   jan          employed      m   59855
# 10685               college   jan          employed      f   61146
# 10686              bachelor   feb          employed      f   39837
#
#       location_code  ...     policy_type        policy  renew_offer_type  \
# 0          suburban  ...  corporate auto  corporate l3            offer3
# 5          suburban  ...   personal auto   personal l3            offer1
# 6             urban  ...  corporate auto  corporate l2            offer2
# 7             urban  ...   personal auto   personal l2            offer2
# 12            rural  ...  corporate auto  corporate l3            offer1
# ...             ...  ...             ...           ...               ...
# 10675         urban  ...   personal auto   personal l2            offer3
# 10676         rural  ...   personal auto   personal l1            offer1
# 10682      suburban  ...   personal auto   personal l2            offer2
# 10685         urban  ...   personal auto   personal l3            offer2
# 10686         rural  ...  corporate auto  corporate l3            offer1
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 0              agent                 292  four-door car      medsize
# 5              agent                 292  four-door car      medsize
# 6             branch                 287  four-door car      medsize
# 7             branch                 247   two-door car      medsize
# 12             agent                  64  four-door car      medsize
# ...              ...                 ...            ...          ...
# 10675          agent                 256  four-door car      medsize
# 10676          agent                 158     sports car      medsize
# 10682         branch                 355   two-door car      medsize
# 10685         branch                 273  four-door car      medsize
# 10686            web                 381     luxury suv      medsize
#
#       total_revenue total_profit percent_profit
# 0              3172         2880       0.907945
# 5              4453         4161       0.934426
# 6              6237         5950       0.953984
# 7              2835         2588       0.912875
# 12             3168         3104       0.979798
# ...             ...          ...            ...
# 10675          4674         4418       0.945229
# 10676          2668         2510       0.940780
# 10682          6068         5713       0.941496
# 10685          4420         4147       0.938235
# 10686         12663        12282       0.969912
#
# [5613 rows x 26 columns]

# %%
sorted_data = data.sort_values(by=['percent_profit'], ascending=False)

# %%
sorted_data[sorted_data['percent_profit']>=0.90]
# Out:
#            region  customer_lifetime_value response  coverage  \
# 6865  west region                     6186       no  extended
# 3628      central                     5004       no     basic
# 2759      central                     4538       no     basic
# 4485  west region                     2494       no     basic
# 7447   north west                    12819       no   premium
# ...           ...                      ...      ...       ...
# 6243      central                     7550       no     basic
# 6906      central                    17651       no  extended
# 6264  west region                     2570       no     basic
# 9843      central                     4984       no     basic
# 9650  west region                     7375       no     basic
#
#                  education month employment_status gender  income  \
# 6865               college   jan          employed      f   88375
# 3628  high school or below   feb          employed      m   86834
# 2759              bachelor   feb          employed      m   82297
# 4485                doctor   feb          employed      m   45855
# 7447                doctor   jan          disabled      f   10105
# ...                    ...   ...               ...    ...     ...
# 6243  high school or below   jan        unemployed      f   69208
# 6906  high school or below   jan     medical leave      f   22510
# 6264  high school or below   feb          employed      f   49304
# 9843               college   feb        unemployed      f   70551
# 9650  high school or below   feb          employed      m   33345
#
#      location_code  ...     policy_type        policy  renew_offer_type  \
# 6865         rural  ...   personal auto   personal l2            offer2
# 3628         rural  ...  corporate auto  corporate l1            offer4
# 2759         rural  ...   personal auto   personal l3            offer1
# 4485         rural  ...   personal auto   personal l3            offer3
# 7447         rural  ...   personal auto   personal l2            offer1
# ...            ...  ...             ...           ...               ...
# 6243      suburban  ...  corporate auto  corporate l3            offer1
# 6906      suburban  ...   personal auto   personal l3            offer1
# 6264      suburban  ...  corporate auto  corporate l2            offer1
# 9843      suburban  ...  corporate auto  corporate l1            offer1
# 9650      suburban  ...  corporate auto  corporate l1            offer1
#
#       sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 6865          agent                   0     luxury car      medsize
# 3628          agent                   0  four-door car      medsize
# 2759    call center                   0     sports car      medsize
# 4485            web                   0  four-door car        large
# 7447         branch                   0            suv      medsize
# ...             ...                 ...            ...          ...
# 6243          agent                 480            suv        small
# 6906            web                 456  four-door car        small
# 6264          agent                 312  four-door car      medsize
# 9843          agent                 336  four-door car        small
# 9650          agent                 338  four-door car      medsize
#
#      total_revenue total_profit percent_profit
# 6865           847          847            1.0
# 3628          5952         5952            1.0
# 2759          7192         7192            1.0
# 4485          1612         1612            1.0
# 7447           688          688            1.0
# ...            ...          ...            ...
# 6243          4800         4320            0.9
# 6906          4560         4104            0.9
# 6264          3120         2808            0.9
# 9843          3360         3024            0.9
# 9650          3380         3042            0.9
#
# [5613 rows x 26 columns]

# %%
sns.scatterplot( x=data.income, y=data.percent_profit);

# %%
data.percent_profit.nunique()
# Out:
# 6972
